# %% [markdown]
# First we will import the dataset

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# Now we will look at our first category:  PassengerId <br>
# Is it categorical or continuous?

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# ...
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Length: 891, dtype: int64

# %% [markdown]
# It is continuous. <br>
# Now we will see if there are missing values.

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# No, there are no null values for passenger id.
# Now lets find the min, max, mean

# %%
df.PassengerId.describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# dtype: float64

# %% [markdown]
# A histogram doesn't really make sense for id but we will try it anyway to see the distribution of ids in 5 bins.

# %%
df.PassengerId.hist(bins=5)

# %% [markdown]
# That didn't mean anything really.  Other than the ids are pretty evenly distributed.
# Now we will do all of the above for survived.

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Survived.hist(bins=2)

# %% [markdown]
# From the above we can see that Survived is categorical with survived = 1, died = 0.  <br>
# There are no null values<br>
# More people died than survived<br>
# Next we will look at Pclass

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Pclass.describe()
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# dtype: float64

# %%
df.Pclass.hist(bins=3)

# %% [markdown]
# We see that Pclass is categorical<br>
# There are no null values<br>
# The majority of passengers were in 3rd class<br>
# Now lets look at Sex:

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# We will use a bar chart here

# %%
df.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# From the above we know Sex is categorical<br>
# There are no null values for Sex<br>
# There were more male passengers than female<br>
# Next we will look at Age

# %%
df.Age.value_counts()
# Out:
# 24    30
# 22    27
# 18    26
# 28    25
# 30    25
# 19    25
# 21    24
# 25    23
# 36    22
# 29    20
# 32    18
# 35    18
# 27    18
# 26    18
# 16    17
# ...
# 53.00    1
# 70.50    1
# 14.50    1
# 0.92     1
# 74.00    1
# 36.50    1
# 80.00    1
# 12.00    1
# 55.50    1
# 34.50    1
# 24.50    1
# 66.00    1
# 23.50    1
# 0.67     1
# 20.50    1
# Length: 88, dtype: int64

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# dtype: float64

# %%
df.Age.hist(bins=10)

# %% [markdown]
# From this we know that Age is continuous.<br>
# There are 177 null values<br>
# The youngest passenger (as far as we know because of nulls) was almost 6 months old.<br>
# The oldest passenger was 80.  <br>
# The average age was 29 which you can also see in the histogram.  The majority of passengers were in their 20's and 30's.<br>
# Now lets look at SibSp.

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# dtype: int64

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.SibSp.value_counts().plot(kind='bar')

# %% [markdown]
# I looked up what SibSp meant, and it is the number of siblings aboard.  <br>
# I am not sure if it is continuous because in theory there is a finite number of siblings you could have.  So for our data I will say categorical.<br>
# There are no null values for SibSp<br>
# The clear majority of passengers did not have siblings aboard the ship with them.<br>

# %%
df.SibSp.describe()
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# dtype: float64

# %% [markdown]
# It looks like the max siblings someone had on board were 8.<br>
# Lets look at Parch.

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# dtype: int64

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Parch.describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# dtype: float64

# %%
df.Parch.hist()

# %% [markdown]
# I will say that this variable could be considered categorical.<br>
# There are no null values for Parch<br>
# It looks like the most children that were brought by parents were 6<br>
# The majority of passengers did not have children on board.<br>
# Now we will look at ticket

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343        7
# 347082          7
# 1601            7
# 347088          6
# CA 2144         6
# 3101295         6
# 382652          5
# S.O.C. 14879    5
# PC 17757        4
# 4133            4
# LINE            4
# 349909          4
# 347077          4
# W./C. 6608      4
# 113760          4
# ...
# STON/O 2. 3101273    1
# 345777               1
# STON/O 2. 3101274    1
# STON/O 2. 3101275    1
# 113794               1
# 2649                 1
# 374887               1
# 349213               1
# 349210               1
# 349242               1
# 349216               1
# 112052               1
# 315088               1
# 349215               1
# W./C. 14258          1
# Length: 681, dtype: int64

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Ticket.describe()
# Out:
# count          891
# unique         681
# top       CA. 2343
# freq             7
# dtype: object

# %% [markdown]
# Ticket seems to be the ticket number and some of them have letters.  This is not a categorical. <br>
# There are no nulls for ticket.<br>
# There were 681 unique ticket numbers out of 891<br>
# This type of data does not work with a graph so lets look at Fare.

# %%
df.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 7.2292     15
# 26.5500    15
# 0.0000     15
# 7.2500     13
# 7.8542     13
# 8.6625     13
# 7.2250     12
# ...
# 15.0000    1
# 28.7125    1
# 61.1750    1
# 6.2375     1
# 15.1000    1
# 39.4000    1
# 81.8583    1
# 61.9792    1
# 7.8000     1
# 22.0250    1
# 47.1000    1
# 13.4167    1
# 14.1083    1
# 15.5500    1
# 13.7917    1
# Length: 248, dtype: int64

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# dtype: float64

# %%
df.Fare.hist(bins=20)

# %% [markdown]
# Fare is a continuous variable.  <br>
# There are no null values in Fare. <br>
# The average ticket price was $32.  The most expensive was $512, the least was free. <br>
# Now we will look at Cabin.

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# ...
# E50    1
# A14    1
# C91    1
# A16    1
# B38    1
# B39    1
# C95    1
# B78    1
# B79    1
# C99    1
# B37    1
# A19    1
# E12    1
# A7     1
# D15    1
# Length: 147, dtype: int64

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
df.Cabin.describe()
# Out:
# count             204
# unique            147
# top       C23 C25 C27
# freq                4
# dtype: object

# %% [markdown]
# Cabin is a continuous variable.<br>
# There are 687 nulls in Cabin so the majority of data is Null. <br>
# We know of the known Cabins, 147 passengers had unique cabins.  But 57 passengers shared a cabin number of those with known cabins.  It seems likely that they were related somehow and were staying in the same cabin.  Of those known cabins, C23, 25, and 27 were the most common.   <br>
# Finally we will look at Embarked.

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572    80   B28      NaN
# 829  female   62      0      0  113572    80   B28      NaN

# %%
df.Embarked.describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# dtype: object

# %%
df.Embarked.value_counts().plot(kind='bar')

# %% [markdown]
# Embarked is Categorical<br>
# There are only two nulls so only two passengers whose Embarked isn't known<br>
# The majority of passengers Embarked at Southhampton, with the least embarking at Queenstown.
